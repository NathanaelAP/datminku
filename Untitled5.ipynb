# %% [markdown]
# <a href="https://colab.research.google.com/github/NathanaelAP/datminku/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

# %%
data_raw = pd.read_csv('C:/Users/HP/Downloads/Data Clean(2)')
data_raw
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-78b5b86db4c1> in <module>
# ----> 1 data_raw = pd.read_csv('C:/Users/HP/Downloads/Data Clean(2)')
#       2 data_raw
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
plt.figure(figsize=(10,6))
ax=sns.barplot(x='primary_use',y='meter_reading',data=data_raw)
plt.xticks(rotation='vertical')
plt.show()
